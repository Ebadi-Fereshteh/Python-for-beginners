# %% [markdown]
# <a href="https://colab.research.google.com/github/Ebadi-Fereshteh/Python_course/blob/main/MLP_prediction_Weather.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install wandb
# Out:
# Collecting wandb
#   Downloading wandb-0.12.11-py2.py3-none-any.whl (1.7 MB)
#      |████████████████████████████████| 1.7 MB 4.3 MB/s
# Requirement already satisfied: protobuf>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (3.17.3)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from wandb) (3.13)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.23.0)
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (7.1.2)
# Collecting pathtools
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
# Collecting yaspin>=1.0.0
#   Downloading yaspin-2.1.0-py3-none-any.whl (18 kB)
# Collecting shortuuid>=0.5.0
#   Downloading shortuuid-1.0.8-py3-none-any.whl (9.5 kB)
# Collecting GitPython>=1.0.0
#   Downloading GitPython-3.1.27-py3-none-any.whl (181 kB)
#      |████████████████████████████████| 181 kB 54.7 MB/s
# Requirement already satisfied: promise<3,>=2.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.3)
# Requirement already satisfied: six>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (1.15.0)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (5.4.8)
# Collecting setproctitle
#   Downloading setproctitle-1.2.2-cp37-cp37m-manylinux1_x86_64.whl (36 kB)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.8.2)
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.5.6-py2.py3-none-any.whl (144 kB)
#      |████████████████████████████████| 144 kB 59.9 MB/s
# Collecting docker-pycreds>=0.4.0
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.9-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 1.8 MB/s
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from GitPython>=1.0.0->wandb) (3.10.0.2)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (1.24.3)
# Requirement already satisfied: termcolor<2.0.0,>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from yaspin>=1.0.0->wandb) (1.1.0)
# Building wheels for collected packages: pathtools
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8806 sha256=6da4c77da71fcba7a3900cdc1142d4753c56f0e5abc3197999c494bb82df03b7
#   Stored in directory: /root/.cache/pip/wheels/3e/31/09/fa59cef12cdcfecc627b3d24273699f390e71828921b2cbba2
# Successfully built pathtools
# Installing collected packages: smmap, gitdb, yaspin, shortuuid, setproctitle, sentry-sdk, pathtools, GitPython, docker-pycreds, wandb
# Successfully installed GitPython-3.1.27 docker-pycreds-0.4.0 gitdb-4.0.9 pathtools-0.1.2 sentry-sdk-1.5.6 setproctitle-1.2.2 shortuuid-1.0.8 smmap-5.0.0 wandb-0.12.11 yaspin-2.1.0

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import tensorflow as tf
from tensorflow.keras.layers import Dense
import numpy as np
import wandb
from wandb.keras import WandbCallback

# %%
data = pd.read_csv("sample_data/weatherHistory.csv")

# %%
data.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# 1                   259.0          15.8263         0.0               1015.63
# 2                   204.0          14.9569         0.0               1015.94
# 3                   269.0          15.8263         0.0               1016.41
# 4                   259.0          15.8263         0.0               1016.51
#
#                        Daily Summary
# 0  Partly cloudy throughout the day.
# 1  Partly cloudy throughout the day.
# 2  Partly cloudy throughout the day.
# 3  Partly cloudy throughout the day.
# 4  Partly cloudy throughout the day.

# %%
data['DateTime'] = pd.to_datetime(data['Formatted Date'], utc=True)

# %%
data['Year'] = data['DateTime'].dt.year

# %%
data['DoY'] = data['DateTime'].dt.dayofyear

# %%
data.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# 1                   259.0          15.8263         0.0               1015.63
# 2                   204.0          14.9569         0.0               1015.94
# 3                   269.0          15.8263         0.0               1016.41
# 4                   259.0          15.8263         0.0               1016.51
#
#                        Daily Summary                  DateTime  Year  DoY
# 0  Partly cloudy throughout the day. 2006-03-31 22:00:00+00:00  2006   90
# 1  Partly cloudy throughout the day. 2006-03-31 23:00:00+00:00  2006   90
# 2  Partly cloudy throughout the day. 2006-04-01 00:00:00+00:00  2006   91
# 3  Partly cloudy throughout the day. 2006-04-01 01:00:00+00:00  2006   91
# 4  Partly cloudy throughout the day. 2006-04-01 02:00:00+00:00  2006   91

# %%
Average_Temperature = data.groupby(['DoY', 'Year'])['Temperature (C)'].mean().reset_index()
Average_Temperature.rename(columns= {'Temperature (C)' : 'Avg_Temperature'}, inplace = True)
Average_Temperature
# Humidity = data.groupby(['DoY', 'Year'])['Humidity'].mean().reset_index()
# Wind Speed (km/h) = data.groupby(['DoY', 'Year'])['Wind Speed (km/h)'].mean().reset_index()
# Wind Bearing (degrees) = data.groupby(['DoY', 'Year'])['Wind Bearing (degrees)'].mean().reset_index()
# Visibility (km) = data.groupby(['DoY', 'Year'])['Visibility (km)'].mean().reset_index()
# Pressure (millibars) = data.groupby(['DoY', 'Year'])['Pressure (millibars)'].mean().reset_index()
# Out:
#       DoY  Year  Avg_Temperature
# 0       1  2006         4.075000
# 1       1  2007         3.806713
# 2       1  2008        -5.663194
# 3       1  2009        -4.850926
# 4       1  2010         7.807407
# ...   ...   ...              ...
# 4014  365  2015        -4.304861
# 4015  365  2016         0.117593
# 4016  366  2008        -6.218056
# 4017  366  2012        -3.249306
# 4018  366  2016         0.113527
#
# [4019 rows x 3 columns]

# %%
X_data = Average_Temperature['DoY'].to_numpy()
X_data = X_data.reshape(-1, 1)
Y_data = Average_Temperature['Avg_Temperature'].to_numpy()
Y_data = Y_data.reshape(-1, 1)

# %%
plt.figure(figsize=(12,4))
plt.grid()
plt.scatter(Average_Temperature['DoY'], Average_Temperature['Avg_Temperature'], marker='.', c='k')
plt.show()

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X_data, Y_data, shuffle=True)

# %%
wandb.init(project= "predict weather")
# Out:
# Finishing last run (ID:3jcp1i2v) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.003 MB of 0.003 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▃▃▄▄▅▅▆▆▇█▁▁▂▃▃▄▄▅▅▆▆▇▇█▁▂▂▃▄▄▅▅▆▆▇▇█</td></tr><tr><td>loss</td><td>█████████████▄▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>299</td></tr><tr><td>loss</td><td>3.08496</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">pious-dust-2</strong>: <a href="https://wandb.ai/fereshteh_ebadi/predict%20weather/runs/3jcp1i2v" target="_blank">https://wandb.ai/fereshteh_ebadi/predict%20weather/runs/3jcp1i2v</a><br/>Synced 5 W&B file(s), 3 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220306_180053-3jcp1i2v/logs</code>
# Successfully finished last run (ID:3jcp1i2v). Initializing new run:<br/>
# Tracking run with wandb version 0.12.11
# Run data is saved locally in <code>/content/wandb/run-20220306_181003-oks7dd01</code>
# Syncing run <strong><a href="https://wandb.ai/fereshteh_ebadi/predict%20weather/runs/oks7dd01" target="_blank">northern-morning-2</a></strong> to <a href="https://wandb.ai/fereshteh_ebadi/predict%20weather" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src="https://wandb.ai/fereshteh_ebadi/predict%20weather/runs/oks7dd01?jupyter=true" style="border:none;width:100%;height:420px;display:none;"></iframe>

# %%
config = wandb.config
config.learning_rate = 0.01

# %%
model = tf.keras.models.Sequential([
        Dense(128, input_dim= 1, activation= "relu"),
        Dense(64, activation= "relu"),
        Dense(32, activation= "relu"),
        # Dense(32, activation= "relu"),
        Dense(1, activation= "linear")
])

# %%
X_train.shape
# Out:
# (3014, 1)

# %%
model.compile(tf.keras.optimizers.Adam(learning_rate= config.learning_rate), 
              loss = tf.keras.losses.MeanAbsoluteError())

# %%
model.summary()
# Out:
# Model: "sequential_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_71 (Dense)            (None, 128)               256
#
#  dense_72 (Dense)            (None, 64)                8256
#
#  dense_73 (Dense)            (None, 32)                2080
#
#  dense_74 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 10,625
# Trainable params: 10,625
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train, Y_train, epochs= 250, callbacks=[WandbCallback()])
# Out:
# Epoch 1/250
# 95/95 [==============================] - 1s 2ms/step - loss: 9.1367 - _timestamp: 1646590217.0000 - _runtime: 9.0000
# Epoch 2/250
# 95/95 [==============================] - 0s 2ms/step - loss: 8.0125 - _timestamp: 1646590217.0000 - _runtime: 9.0000
# Epoch 3/250
# 95/95 [==============================] - 0s 2ms/step - loss: 7.5743 - _timestamp: 1646590218.0000 - _runtime: 10.0000
# Epoch 4/250
# 95/95 [==============================] - 0s 2ms/step - loss: 7.3248 - _timestamp: 1646590218.0000 - _runtime: 10.0000
# Epoch 5/250
# 95/95 [==============================] - 0s 2ms/step - loss: 7.0083 - _timestamp: 1646590218.0000 - _runtime: 10.0000
# Epoch 6/250
# 95/95 [==============================] - 0s 2ms/step - loss: 6.8384 - _timestamp: 1646590218.0000 - _runtime: 10.0000
# Epoch 7/250
# 95/95 [==============================] - 0s 2ms/step - loss: 6.2043 - _timestamp: 1646590218.0000 - _runtime: 10.0000
# Epoch 8/250
# 95/95 [==============================] - 0s 2ms/step - loss: 5.7530 - _timestamp: 1646590219.0000 - _runtime: 11.0000
# Epoch 9/250
# 95/95 [==============================] - 0s 2ms/step - loss: 4.6747 - _timestamp: 1646590219.0000 - _runtime: 11.0000
# Epoch 10/250
# 95/95 [==============================] - 0s 2ms/step - loss: 4.0028 - _timestamp: 1646590219.0000 - _runtime: 11.0000
# Epoch 11/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.6223 - _timestamp: 1646590219.0000 - _runtime: 11.0000
# Epoch 12/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.8072 - _timestamp: 1646590219.0000 - _runtime: 11.0000
# Epoch 13/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.3806 - _timestamp: 1646590220.0000 - _runtime: 12.0000
# Epoch 14/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.2877 - _timestamp: 1646590220.0000 - _runtime: 12.0000
# Epoch 15/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.4104 - _timestamp: 1646590220.0000 - _runtime: 12.0000
# Epoch 16/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.2042 - _timestamp: 1646590220.0000 - _runtime: 12.0000
# Epoch 17/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.4360 - _timestamp: 1646590221.0000 - _runtime: 13.0000
# Epoch 18/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.1685 - _timestamp: 1646590221.0000 - _runtime: 13.0000
# Epoch 19/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.1420 - _timestamp: 1646590221.0000 - _runtime: 13.0000
# Epoch 20/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.1755 - _timestamp: 1646590221.0000 - _runtime: 13.0000
# Epoch 21/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.1336 - _timestamp: 1646590221.0000 - _runtime: 13.0000
# Epoch 22/250
# 95/95 [==============================] - 0s 3ms/step - loss: 3.2190 - _timestamp: 1646590222.0000 - _runtime: 14.0000
# Epoch 23/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.2303 - _timestamp: 1646590222.0000 - _runtime: 14.0000
# Epoch 24/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.3651 - _timestamp: 1646590222.0000 - _runtime: 14.0000
# Epoch 25/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.1712 - _timestamp: 1646590222.0000 - _runtime: 14.0000
# Epoch 26/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.1297 - _timestamp: 1646590222.0000 - _runtime: 14.0000
# Epoch 27/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0662 - _timestamp: 1646590223.0000 - _runtime: 15.0000
# Epoch 28/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.1147 - _timestamp: 1646590223.0000 - _runtime: 15.0000
# Epoch 29/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0909 - _timestamp: 1646590223.0000 - _runtime: 15.0000
# Epoch 30/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.2762 - _timestamp: 1646590223.0000 - _runtime: 15.0000
# Epoch 31/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.1245 - _timestamp: 1646590223.0000 - _runtime: 15.0000
# Epoch 32/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.1547 - _timestamp: 1646590224.0000 - _runtime: 16.0000
# Epoch 33/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0868 - _timestamp: 1646590224.0000 - _runtime: 16.0000
# Epoch 34/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0956 - _timestamp: 1646590224.0000 - _runtime: 16.0000
# Epoch 35/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0995 - _timestamp: 1646590224.0000 - _runtime: 16.0000
# Epoch 36/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.1342 - _timestamp: 1646590224.0000 - _runtime: 16.0000
# Epoch 37/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.1385 - _timestamp: 1646590225.0000 - _runtime: 17.0000
# Epoch 38/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0631 - _timestamp: 1646590225.0000 - _runtime: 17.0000
# Epoch 39/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.1157 - _timestamp: 1646590225.0000 - _runtime: 17.0000
# Epoch 40/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0578 - _timestamp: 1646590225.0000 - _runtime: 17.0000
# Epoch 41/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.1367 - _timestamp: 1646590225.0000 - _runtime: 17.0000
# Epoch 42/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0905 - _timestamp: 1646590226.0000 - _runtime: 18.0000
# Epoch 43/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0944 - _timestamp: 1646590226.0000 - _runtime: 18.0000
# Epoch 44/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0780 - _timestamp: 1646590226.0000 - _runtime: 18.0000
# Epoch 45/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.1173 - _timestamp: 1646590226.0000 - _runtime: 18.0000
# Epoch 46/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.1067 - _timestamp: 1646590226.0000 - _runtime: 18.0000
# Epoch 47/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.1391 - _timestamp: 1646590227.0000 - _runtime: 19.0000
# Epoch 48/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.1615 - _timestamp: 1646590227.0000 - _runtime: 19.0000
# Epoch 49/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0944 - _timestamp: 1646590227.0000 - _runtime: 19.0000
# Epoch 50/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0480 - _timestamp: 1646590227.0000 - _runtime: 19.0000
# Epoch 51/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0536 - _timestamp: 1646590227.0000 - _runtime: 19.0000
# Epoch 52/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.1109 - _timestamp: 1646590228.0000 - _runtime: 20.0000
# Epoch 53/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0620 - _timestamp: 1646590228.0000 - _runtime: 20.0000
# Epoch 54/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0533 - _timestamp: 1646590228.0000 - _runtime: 20.0000
# Epoch 55/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0682 - _timestamp: 1646590228.0000 - _runtime: 20.0000
# Epoch 56/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.1554 - _timestamp: 1646590228.0000 - _runtime: 20.0000
# Epoch 57/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0696 - _timestamp: 1646590229.0000 - _runtime: 21.0000
# Epoch 58/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0583 - _timestamp: 1646590229.0000 - _runtime: 21.0000
# Epoch 59/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0641 - _timestamp: 1646590229.0000 - _runtime: 21.0000
# Epoch 60/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.1178 - _timestamp: 1646590229.0000 - _runtime: 21.0000
# Epoch 61/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0642 - _timestamp: 1646590229.0000 - _runtime: 21.0000
# Epoch 62/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.1537 - _timestamp: 1646590230.0000 - _runtime: 22.0000
# Epoch 63/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.1132 - _timestamp: 1646590230.0000 - _runtime: 22.0000
# Epoch 64/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0822 - _timestamp: 1646590230.0000 - _runtime: 22.0000
# Epoch 65/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.1075 - _timestamp: 1646590230.0000 - _runtime: 22.0000
# Epoch 66/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0748 - _timestamp: 1646590230.0000 - _runtime: 22.0000
# Epoch 67/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0951 - _timestamp: 1646590231.0000 - _runtime: 23.0000
# Epoch 68/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0258 - _timestamp: 1646590231.0000 - _runtime: 23.0000
# Epoch 69/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0794 - _timestamp: 1646590231.0000 - _runtime: 23.0000
# Epoch 70/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.1939 - _timestamp: 1646590231.0000 - _runtime: 23.0000
# Epoch 71/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0783 - _timestamp: 1646590231.0000 - _runtime: 23.0000
# Epoch 72/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.1734 - _timestamp: 1646590232.0000 - _runtime: 24.0000
# Epoch 73/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.1414 - _timestamp: 1646590232.0000 - _runtime: 24.0000
# Epoch 74/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0722 - _timestamp: 1646590232.0000 - _runtime: 24.0000
# Epoch 75/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.1420 - _timestamp: 1646590232.0000 - _runtime: 24.0000
# Epoch 76/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0534 - _timestamp: 1646590232.0000 - _runtime: 24.0000
# Epoch 77/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0417 - _timestamp: 1646590233.0000 - _runtime: 25.0000
# Epoch 78/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0811 - _timestamp: 1646590233.0000 - _runtime: 25.0000
# Epoch 79/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0435 - _timestamp: 1646590233.0000 - _runtime: 25.0000
# Epoch 80/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0658 - _timestamp: 1646590233.0000 - _runtime: 25.0000
# Epoch 81/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0905 - _timestamp: 1646590233.0000 - _runtime: 25.0000
# Epoch 82/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.1622 - _timestamp: 1646590234.0000 - _runtime: 26.0000
# Epoch 83/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.2524 - _timestamp: 1646590234.0000 - _runtime: 26.0000
# Epoch 84/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0210 - _timestamp: 1646590234.0000 - _runtime: 26.0000
# Epoch 85/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0490 - _timestamp: 1646590234.0000 - _runtime: 26.0000
# Epoch 86/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0870 - _timestamp: 1646590235.0000 - _runtime: 27.0000
# Epoch 87/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0938 - _timestamp: 1646590235.0000 - _runtime: 27.0000
# Epoch 88/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0374 - _timestamp: 1646590235.0000 - _runtime: 27.0000
# Epoch 89/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.1447 - _timestamp: 1646590235.0000 - _runtime: 27.0000
# Epoch 90/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0553 - _timestamp: 1646590235.0000 - _runtime: 27.0000
# Epoch 91/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0499 - _timestamp: 1646590236.0000 - _runtime: 28.0000
# Epoch 92/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0178 - _timestamp: 1646590236.0000 - _runtime: 28.0000
# Epoch 93/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0064 - _timestamp: 1646590236.0000 - _runtime: 28.0000
# Epoch 94/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0614 - _timestamp: 1646590236.0000 - _runtime: 28.0000
# Epoch 95/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0389 - _timestamp: 1646590236.0000 - _runtime: 28.0000
# Epoch 96/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0673 - _timestamp: 1646590237.0000 - _runtime: 29.0000
# Epoch 97/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.1472 - _timestamp: 1646590237.0000 - _runtime: 29.0000
# Epoch 98/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.1213 - _timestamp: 1646590237.0000 - _runtime: 29.0000
# Epoch 99/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0809 - _timestamp: 1646590237.0000 - _runtime: 29.0000
# Epoch 100/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0990 - _timestamp: 1646590237.0000 - _runtime: 29.0000
# Epoch 101/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0975 - _timestamp: 1646590238.0000 - _runtime: 30.0000
# Epoch 102/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0362 - _timestamp: 1646590238.0000 - _runtime: 30.0000
# Epoch 103/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0565 - _timestamp: 1646590238.0000 - _runtime: 30.0000
# Epoch 104/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0379 - _timestamp: 1646590238.0000 - _runtime: 30.0000
# Epoch 105/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0976 - _timestamp: 1646590238.0000 - _runtime: 30.0000
# Epoch 106/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.1756 - _timestamp: 1646590239.0000 - _runtime: 31.0000
# Epoch 107/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0422 - _timestamp: 1646590239.0000 - _runtime: 31.0000
# Epoch 108/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0787 - _timestamp: 1646590239.0000 - _runtime: 31.0000
# Epoch 109/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0519 - _timestamp: 1646590239.0000 - _runtime: 31.0000
# Epoch 110/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0666 - _timestamp: 1646590239.0000 - _runtime: 31.0000
# Epoch 111/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.1571 - _timestamp: 1646590240.0000 - _runtime: 32.0000
# Epoch 112/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0452 - _timestamp: 1646590240.0000 - _runtime: 32.0000
# Epoch 113/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0441 - _timestamp: 1646590240.0000 - _runtime: 32.0000
# Epoch 114/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0037 - _timestamp: 1646590240.0000 - _runtime: 32.0000
# Epoch 115/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.1499 - _timestamp: 1646590241.0000 - _runtime: 33.0000
# Epoch 116/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0294 - _timestamp: 1646590241.0000 - _runtime: 33.0000
# Epoch 117/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0975 - _timestamp: 1646590241.0000 - _runtime: 33.0000
# Epoch 118/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0602 - _timestamp: 1646590241.0000 - _runtime: 33.0000
# Epoch 119/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0464 - _timestamp: 1646590241.0000 - _runtime: 33.0000
# Epoch 120/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0389 - _timestamp: 1646590242.0000 - _runtime: 34.0000
# Epoch 121/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0573 - _timestamp: 1646590242.0000 - _runtime: 34.0000
# Epoch 122/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.1005 - _timestamp: 1646590242.0000 - _runtime: 34.0000
# Epoch 123/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0466 - _timestamp: 1646590242.0000 - _runtime: 34.0000
# Epoch 124/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.1404 - _timestamp: 1646590242.0000 - _runtime: 34.0000
# Epoch 125/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0348 - _timestamp: 1646590243.0000 - _runtime: 35.0000
# Epoch 126/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0619 - _timestamp: 1646590243.0000 - _runtime: 35.0000
# Epoch 127/250
# 95/95 [==============================] - 0s 2ms/step - loss: 2.9828 - _timestamp: 1646590243.0000 - _runtime: 35.0000
# Epoch 128/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0992 - _timestamp: 1646590243.0000 - _runtime: 35.0000
# Epoch 129/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0597 - _timestamp: 1646590244.0000 - _runtime: 36.0000
# Epoch 130/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0560 - _timestamp: 1646590244.0000 - _runtime: 36.0000
# Epoch 131/250
# 95/95 [==============================] - 0s 2ms/step - loss: 2.9801 - _timestamp: 1646590244.0000 - _runtime: 36.0000
# Epoch 132/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0641 - _timestamp: 1646590244.0000 - _runtime: 36.0000
# Epoch 133/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.1226 - _timestamp: 1646590244.0000 - _runtime: 36.0000
# Epoch 134/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.1155 - _timestamp: 1646590245.0000 - _runtime: 37.0000
# Epoch 135/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0217 - _timestamp: 1646590245.0000 - _runtime: 37.0000
# Epoch 136/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0669 - _timestamp: 1646590245.0000 - _runtime: 37.0000
# Epoch 137/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.1020 - _timestamp: 1646590245.0000 - _runtime: 37.0000
# Epoch 138/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0181 - _timestamp: 1646590245.0000 - _runtime: 37.0000
# Epoch 139/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.1093 - _timestamp: 1646590246.0000 - _runtime: 38.0000
# Epoch 140/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0083 - _timestamp: 1646590246.0000 - _runtime: 38.0000
# Epoch 141/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0772 - _timestamp: 1646590246.0000 - _runtime: 38.0000
# Epoch 142/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0673 - _timestamp: 1646590246.0000 - _runtime: 38.0000
# Epoch 143/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.1168 - _timestamp: 1646590246.0000 - _runtime: 38.0000
# Epoch 144/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.1334 - _timestamp: 1646590247.0000 - _runtime: 39.0000
# Epoch 145/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0876 - _timestamp: 1646590247.0000 - _runtime: 39.0000
# Epoch 146/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0603 - _timestamp: 1646590247.0000 - _runtime: 39.0000
# Epoch 147/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0497 - _timestamp: 1646590247.0000 - _runtime: 39.0000
# Epoch 148/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0118 - _timestamp: 1646590248.0000 - _runtime: 40.0000
# Epoch 149/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0389 - _timestamp: 1646590248.0000 - _runtime: 40.0000
# Epoch 150/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0131 - _timestamp: 1646590248.0000 - _runtime: 40.0000
# Epoch 151/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0102 - _timestamp: 1646590248.0000 - _runtime: 40.0000
# Epoch 152/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0554 - _timestamp: 1646590248.0000 - _runtime: 40.0000
# Epoch 153/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0637 - _timestamp: 1646590249.0000 - _runtime: 41.0000
# Epoch 154/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0520 - _timestamp: 1646590249.0000 - _runtime: 41.0000
# Epoch 155/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0373 - _timestamp: 1646590249.0000 - _runtime: 41.0000
# Epoch 156/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0375 - _timestamp: 1646590249.0000 - _runtime: 41.0000
# Epoch 157/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0098 - _timestamp: 1646590250.0000 - _runtime: 42.0000
# Epoch 158/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0117 - _timestamp: 1646590250.0000 - _runtime: 42.0000
# Epoch 159/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0752 - _timestamp: 1646590250.0000 - _runtime: 42.0000
# Epoch 160/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0802 - _timestamp: 1646590250.0000 - _runtime: 42.0000
# Epoch 161/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0470 - _timestamp: 1646590250.0000 - _runtime: 42.0000
# Epoch 162/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0448 - _timestamp: 1646590251.0000 - _runtime: 43.0000
# Epoch 163/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.2060 - _timestamp: 1646590251.0000 - _runtime: 43.0000
# Epoch 164/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0173 - _timestamp: 1646590251.0000 - _runtime: 43.0000
# Epoch 165/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0415 - _timestamp: 1646590251.0000 - _runtime: 43.0000
# Epoch 166/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0533 - _timestamp: 1646590252.0000 - _runtime: 44.0000
# Epoch 167/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0580 - _timestamp: 1646590252.0000 - _runtime: 44.0000
# Epoch 168/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0569 - _timestamp: 1646590252.0000 - _runtime: 44.0000
# Epoch 169/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0540 - _timestamp: 1646590252.0000 - _runtime: 44.0000
# Epoch 170/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0216 - _timestamp: 1646590252.0000 - _runtime: 44.0000
# Epoch 171/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0432 - _timestamp: 1646590253.0000 - _runtime: 45.0000
# Epoch 172/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0104 - _timestamp: 1646590253.0000 - _runtime: 45.0000
# Epoch 173/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.1169 - _timestamp: 1646590253.0000 - _runtime: 45.0000
# Epoch 174/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0573 - _timestamp: 1646590253.0000 - _runtime: 45.0000
# Epoch 175/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0241 - _timestamp: 1646590254.0000 - _runtime: 46.0000
# Epoch 176/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0000 - _timestamp: 1646590254.0000 - _runtime: 46.0000
# Epoch 177/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0813 - _timestamp: 1646590254.0000 - _runtime: 46.0000
# Epoch 178/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0221 - _timestamp: 1646590254.0000 - _runtime: 46.0000
# Epoch 179/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.1086 - _timestamp: 1646590254.0000 - _runtime: 46.0000
# Epoch 180/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.2379 - _timestamp: 1646590255.0000 - _runtime: 47.0000
# Epoch 181/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0708 - _timestamp: 1646590255.0000 - _runtime: 47.0000
# Epoch 182/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0417 - _timestamp: 1646590255.0000 - _runtime: 47.0000
# Epoch 183/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0723 - _timestamp: 1646590255.0000 - _runtime: 47.0000
# Epoch 184/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0923 - _timestamp: 1646590255.0000 - _runtime: 47.0000
# Epoch 185/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0398 - _timestamp: 1646590256.0000 - _runtime: 48.0000
# Epoch 186/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0321 - _timestamp: 1646590256.0000 - _runtime: 48.0000
# Epoch 187/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0556 - _timestamp: 1646590256.0000 - _runtime: 48.0000
# Epoch 188/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0815 - _timestamp: 1646590256.0000 - _runtime: 48.0000
# Epoch 189/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.1421 - _timestamp: 1646590257.0000 - _runtime: 49.0000
# Epoch 190/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0690 - _timestamp: 1646590257.0000 - _runtime: 49.0000
# Epoch 191/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0401 - _timestamp: 1646590257.0000 - _runtime: 49.0000
# Epoch 192/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0131 - _timestamp: 1646590257.0000 - _runtime: 49.0000
# Epoch 193/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0258 - _timestamp: 1646590257.0000 - _runtime: 49.0000
# Epoch 194/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0664 - _timestamp: 1646590258.0000 - _runtime: 50.0000
# Epoch 195/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0617 - _timestamp: 1646590258.0000 - _runtime: 50.0000
# Epoch 196/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0296 - _timestamp: 1646590258.0000 - _runtime: 50.0000
# Epoch 197/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0982 - _timestamp: 1646590258.0000 - _runtime: 50.0000
# Epoch 198/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0217 - _timestamp: 1646590259.0000 - _runtime: 51.0000
# Epoch 199/250
# 95/95 [==============================] - 0s 2ms/step - loss: 2.9965 - _timestamp: 1646590259.0000 - _runtime: 51.0000
# Epoch 200/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0169 - _timestamp: 1646590259.0000 - _runtime: 51.0000
# Epoch 201/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0471 - _timestamp: 1646590259.0000 - _runtime: 51.0000
# Epoch 202/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0494 - _timestamp: 1646590259.0000 - _runtime: 51.0000
# Epoch 203/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0708 - _timestamp: 1646590260.0000 - _runtime: 52.0000
# Epoch 204/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.1562 - _timestamp: 1646590260.0000 - _runtime: 52.0000
# Epoch 205/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0157 - _timestamp: 1646590260.0000 - _runtime: 52.0000
# Epoch 206/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0842 - _timestamp: 1646590260.0000 - _runtime: 52.0000
# Epoch 207/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0160 - _timestamp: 1646590261.0000 - _runtime: 53.0000
# Epoch 208/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0523 - _timestamp: 1646590261.0000 - _runtime: 53.0000
# Epoch 209/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0963 - _timestamp: 1646590261.0000 - _runtime: 53.0000
# Epoch 210/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.1768 - _timestamp: 1646590261.0000 - _runtime: 53.0000
# Epoch 211/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0047 - _timestamp: 1646590261.0000 - _runtime: 53.0000
# Epoch 212/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0083 - _timestamp: 1646590262.0000 - _runtime: 54.0000
# Epoch 213/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0768 - _timestamp: 1646590262.0000 - _runtime: 54.0000
# Epoch 214/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.1083 - _timestamp: 1646590262.0000 - _runtime: 54.0000
# Epoch 215/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0961 - _timestamp: 1646590262.0000 - _runtime: 54.0000
# Epoch 216/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0662 - _timestamp: 1646590263.0000 - _runtime: 55.0000
# Epoch 217/250
# 95/95 [==============================] - 0s 2ms/step - loss: 2.9865 - _timestamp: 1646590263.0000 - _runtime: 55.0000
# Epoch 218/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0890 - _timestamp: 1646590263.0000 - _runtime: 55.0000
# Epoch 219/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0524 - _timestamp: 1646590263.0000 - _runtime: 55.0000
# Epoch 220/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0967 - _timestamp: 1646590263.0000 - _runtime: 55.0000
# Epoch 221/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0898 - _timestamp: 1646590264.0000 - _runtime: 56.0000
# Epoch 222/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0333 - _timestamp: 1646590264.0000 - _runtime: 56.0000
# Epoch 223/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0292 - _timestamp: 1646590264.0000 - _runtime: 56.0000
# Epoch 224/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0524 - _timestamp: 1646590264.0000 - _runtime: 56.0000
# Epoch 225/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0422 - _timestamp: 1646590265.0000 - _runtime: 57.0000
# Epoch 226/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0478 - _timestamp: 1646590265.0000 - _runtime: 57.0000
# Epoch 227/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.1042 - _timestamp: 1646590265.0000 - _runtime: 57.0000
# Epoch 228/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0415 - _timestamp: 1646590265.0000 - _runtime: 57.0000
# Epoch 229/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0525 - _timestamp: 1646590265.0000 - _runtime: 57.0000
# Epoch 230/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0291 - _timestamp: 1646590266.0000 - _runtime: 58.0000
# Epoch 231/250
# 95/95 [==============================] - 0s 2ms/step - loss: 2.9837 - _timestamp: 1646590266.0000 - _runtime: 58.0000
# Epoch 232/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.1001 - _timestamp: 1646590266.0000 - _runtime: 58.0000
# Epoch 233/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0852 - _timestamp: 1646590266.0000 - _runtime: 58.0000
# Epoch 234/250
# 95/95 [==============================] - 0s 3ms/step - loss: 3.0994 - _timestamp: 1646590267.0000 - _runtime: 59.0000
# Epoch 235/250
# 95/95 [==============================] - 0s 3ms/step - loss: 3.0239 - _timestamp: 1646590267.0000 - _runtime: 59.0000
# Epoch 236/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0047 - _timestamp: 1646590267.0000 - _runtime: 59.0000
# Epoch 237/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0625 - _timestamp: 1646590267.0000 - _runtime: 59.0000
# Epoch 238/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0334 - _timestamp: 1646590267.0000 - _runtime: 59.0000
# Epoch 239/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0909 - _timestamp: 1646590268.0000 - _runtime: 60.0000
# Epoch 240/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0155 - _timestamp: 1646590268.0000 - _runtime: 60.0000
# Epoch 241/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0759 - _timestamp: 1646590268.0000 - _runtime: 60.0000
# Epoch 242/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0795 - _timestamp: 1646590268.0000 - _runtime: 60.0000
# Epoch 243/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.1053 - _timestamp: 1646590269.0000 - _runtime: 61.0000
# Epoch 244/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0581 - _timestamp: 1646590269.0000 - _runtime: 61.0000
# Epoch 245/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0650 - _timestamp: 1646590269.0000 - _runtime: 61.0000
# Epoch 246/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.1007 - _timestamp: 1646590269.0000 - _runtime: 61.0000
# Epoch 247/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.3231 - _timestamp: 1646590269.0000 - _runtime: 61.0000
# Epoch 248/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0234 - _timestamp: 1646590270.0000 - _runtime: 62.0000
# Epoch 249/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0382 - _timestamp: 1646590270.0000 - _runtime: 62.0000
# Epoch 250/250
# 95/95 [==============================] - 0s 2ms/step - loss: 3.0285 - _timestamp: 1646590270.0000 - _runtime: 62.0000

# %%
model.evaluate(X_test, Y_test)
# Out:
# 32/32 [==============================] - 0s 2ms/step - loss: 3.0742
# 3.0742368698120117

# %%
Y_pred = model.predict(X_train)

plt.figure(figsize=(12, 6))
plt.scatter(X_train, Y_train, marker='.', c='k', label='Train Data')
plt.plot(X_train, Y_pred, 'o' , color='red',  label='Fitted line')
plt.xlabel('DoY')
plt.ylabel('Avg_Temperature')
plt.title('Average Day Temperature')
plt.legend()
plt.show()

Y_pred = model.predict(X_test)

plt.figure(figsize=(12, 6))
plt.scatter(X_test, Y_test, marker='.', c='k', label='Test Data')
plt.plot(X_test, Y_pred, 'o' , color='red',  label='Fitted line')
plt.xlabel('DoY')
plt.ylabel('Avg_Temperature')
plt.title('Average Day Temperature')
plt.legend()
plt.show()
